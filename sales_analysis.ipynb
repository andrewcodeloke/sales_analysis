# %% [markdown]
# <h2> OBJECTIVES
#
# 1. Identify overall sales trend?
# 2. What are top 10 products by sales?
# 3. What are the highest selling products by quantity?
# 4. Which is preferred shipment mode?
# 5. Which are the most profitable categories and sub-categories?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel('sales.xlsx')

# %% [markdown]
# <h1> DATA AUDIT

# %%
df.head(10)
# Out:
#           order_id order_date  ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class   Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class     Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class      Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 5    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 6     CA-2011-1510 2011-01-02 2011-01-06  Standard Class   Magdelene Morse
# 7    IN-2011-79397 2011-01-03 2011-01-03        Same Day       Kean Nguyen
# 8    ID-2011-80230 2011-01-03 2011-01-09  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680 2011-01-03 2011-01-07  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...
# ...

# %%
df.tail(5)
# Out:
#              order_id order_date  ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51286    MO-2014-2560 2014-12-31 2015-01-05  Standard Class         Liz Preis
# 51287  MX-2014-110527 2014-12-31 2015-01-02    Second Class  Charlotte Melton
# 51288  MX-2014-114783 2014-12-31 2015-01-06  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720 2014-12-31 2015-01-04  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %% [markdown]
# <h1> DATA CLEANING

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# DATA ANALYSIS

# %%
df.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# std      487.565361      2.278766      0.212280    174.424113      57.296810
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
#
#                year
# count  51290.000000
# mean    2012.777208
# std        1.098931
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %% [markdown]
# <h1>1. OVERALL SALES TREND

# %%
df['order_date'].min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
df['order_date'].max()
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
# getting month and year out of original dataset 
df['month_year'] = df['order_date'].apply(lambda x: x.strftime('%Y-%m'))
df
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 0         AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# 1        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# 2         HU-2011-1220 2011-01-01 2011-01-05    Second Class
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 4        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# ...                ...        ...        ...             ...
# 51285   CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287   MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288   MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
trend = df.groupby('month_year').sum(numeric_only=True)['sales'].reset_index()

# %%
plt.figure(figsize=(15,6))
plt.plot(trend['month_year'], trend['sales'],color='green')
plt.xticks(rotation='vertical',size=8)
plt.title('Sales Trend')
plt.xlabel('month_year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <h1> 2. TOP TEN PRODUCTS BY SALES

# %%
# grouping by product name column + placing it in pandas data frame
prdt_sales = pd.DataFrame(df.groupby('product_name').sum(numeric_only=True)['sales'])

# %%
# sorting product sales in descending order
prdt_sales = prdt_sales.sort_values('sales',ascending=False)

# %%
# top ten product by sales
prdt_sales = prdt_sales[:10]

# %%
plt.bar(prdt_sales.index,prdt_sales['sales'],color='red')
plt.xticks(rotation='vertical',size=8)
plt.title('Top Ten Products by Sales')
plt.xlabel('Product Names')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <h1> 3. HIGHEST SELLING PRODUCTS BY QUANTITY

# %%
# group by quantity sold for produts
prdt_quantity = pd.DataFrame(df.groupby('product_name').sum(numeric_only=True)['quantity'])

# %%
# sort by 
prdt_quantity = prdt_quantity.sort_values('quantity',ascending=False)

# %%
prdt_quantity = prdt_quantity.head(10)
prdt_quantity.head(10)
# Out:
#                                        quantity
# product_name
# Staples                                     876
# Cardinal Index Tab, Clear                   337
# Eldon File Cart, Single Width               321
# Rogers File Cart, Single Width              262
# Sanford Pencil Sharpener, Water Color       259
# Stockwell Paper Clips, Assorted Sizes       253
# Avery Index Tab, Clear                      252
# Ibico Index Tab, Clear                      251
# Smead File Cart, Single Width               250
# Stanley Pencil Sharpener, Water Color       242

# %%
plt.bar(prdt_quantity.index,prdt_quantity['quantity'],color='blue')
plt.xticks(rotation='vertical',size=8)
plt.title('Top Ten Products by Sales Quantity')
plt.xlabel('Product Names')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <h1> 4. MOST PREFERRED MODE OF SHIPMENT

# %%
prf_shipment = pd.DataFrame(df['ship_mode'].value_counts())

# %%
prf_shipment
# Out:
#                 ship_mode
# Standard Class      30775
# Second Class        10309
# First Class          7505
# Same Day             2701

# %%
plt.pie(prf_shipment['ship_mode'], labels=prf_shipment.index, autopct='%1.2f%%') #autopct adjusts decimal display
plt.show()

# %% [markdown]
# - Standard Class most common mode of shipment

# %% [markdown]
# <h1> 5. MOST PROFITABLE CATEGORY AND SUB-CATEGORY

# %%
cat_subcat = pd.DataFrame(df.groupby(['category','sub_category']).sum(numeric_only=True)['profit'])

# %%
cat_subcat = cat_subcat.sort_values(['category','profit'],ascending=False)

# %%
cat_subcat
# Out:
#                                     profit
# category        sub_category
# Technology      Copiers       258567.54818
#                 Phones        216717.00580
#                 Accessories   129626.30620
#                 Machines       58867.87300
# Office Supplies Appliances    141680.58940
#                 Storage       108461.48980
#                 Binders        72449.84600
#                 Paper          59207.68270
#                 Art            57953.91090
#                 Envelopes      29601.11630
#                 Supplies       22583.26310
#                 Labels         15010.51200
#                 Fasteners      11525.42410
# Furniture       Bookcases     161924.41950
#                 Chairs        141973.79750
#                 Furnishings    46967.42550
#                 Tables        -64083.38870

# %%
# Pivot the DataFrame for stacked bar chart
pivot_df = cat_subcat.reset_index().pivot(index='category', columns='sub_category', values='profit')

# .pivot function uses category as index and sub-category as separate column

# Plot the stacked bar chart
plt.figure(figsize=(12, 8))
pivot_df.plot(kind='bar', stacked=True)
plt.xlabel('Category')
plt.ylabel('Profit')
plt.title('Stacked Bar Chart - Category vs Sub-Category Profit')
plt.legend(title='Sub-Category', bbox_to_anchor=(1.01, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> END OF ANALYSIS
